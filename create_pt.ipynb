# %% [markdown]
# <a href="https://colab.research.google.com/github/Keiichiro-Harry/Object_Detection/blob/main/create_pt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
WORKING_DIR = '/content/tmp'
# !mkdir $WORKING_DIR
# %cd $WORKING_DIR
# Out:
# /content/tmp

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15529, done.
# remote: Counting objects: 100% (136/136), done.
# remote: Compressing objects: 100% (93/93), done.
# remote: Total 15529 (delta 49), reused 119 (delta 43), pack-reused 15393
# Receiving objects: 100% (15529/15529), 14.59 MiB | 29.87 MiB/s, done.
# Resolving deltas: 100% (10577/10577), done.

# %%
# %cd yolov5/
# Out:
# /content/tmp/yolov5

# %%
# !pip install imgaug==0.2.5
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 562.7/562.7 kB 10.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for imgaug: filename=imgaug-0.2.5-py3-none-any.whl size=561439 sha256=2e6448a32460c749371f1b5c9c3ab0e97ebc90a147f285850968dde88dba2529
#   Stored in directory: /root/.cache/pip/wheels/15/ce/73/56b66fd453b11dcfbdb7bff1f4b2c1d448eba44f2212fb3d3b
# Successfully built imgaug
# ...
#   Attempting uninstall: imgaug
#     Found existing installation: imgaug 0.4.0
#     Uninstalling imgaug-0.4.0:
#       Successfully uninstalled imgaug-0.4.0
# ...

# %%
# !pip install -qr requirements.txt
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 5.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 9.3 MB/s eta 0:00:00

# %%
# !python train.py --img 640 --batch 5 --epochs 100 --data '/content/drive/My Drive/RoboCup2023/dataset.yaml' --name object_detection
# Out:
# train: weights=yolov5s.pt, cfg=, data=/content/drive/My Drive/RoboCup2023/dataset.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=5, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=object_detection, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# requirements: /content/tmp/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-145-g94714fe Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
# !python detect.py --source data/images/0.png --conf 0.5 --weights runs/train/object_detection2/weights/best.pt
# Out:
# detect: weights=['runs/train/object_detection2/weights/best.pt'], source=data/images/0.png, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# requirements: /content/tmp/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-145-g94714fe Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/tmp/yolov5/data/images/0.png: 640x640 1 H, 11.5ms
# Speed: 0.6ms pre-process, 11.5ms inference, 1.8ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp2
